# %% [markdown]
# OOPS> OBJECT ORIENTED PROGRAMMING IN PYTHON

# %%
class xyz:
  p=20       #Global Variables
  q=30

  def fun1(self):   #Method
     print('The values of p:',self.p)

  def fun2(self,b):     #b is a loacl variable
      m= b*self.p
      return m


object= xyz()

# %%
object.fun1()
# Out:
# The values of p: 20

# %%
object.fun2(7)
# Out:
# 140

# %%
from os import name
class Dog:
  def __init__(self,name):
    self.name= name

  def talk(self):
    print("Woof !")

  def printname(self):
    print("My Name is:{}".format(self.name))

# %%
dog=Dog("charlie")
dog.talk()
# Out:
# Woof !

# %%
dog.printname()
# Out:
# My Name is:charlie

# %%
class faculty:
  def data(self):
   self.id=int(input("Enter faculty id:\n"))
   self.name=input("Enter name of faculty:\n")
   self.salary=int(input("Enter faculty salary:\n"))

  def show(self):
    print("Faculty id:", self.id)
    print("Faculty name:", self.name)
    print("Faculty salary:", self.salary)

# %%
f_data=faculty()

# %%
f_data.data()
# Out:
# Enter faculty id:
# 20
# Enter name of faculty:
# sandeep
# Enter faculty salary:
# 30000

# %%
f_data.show()
# Out:
# Faculty id: 20
# Faculty name: sandeep
# Faculty salary: 30000

# %%
class Faculty:
  def __init__(self,id,name,salary):
    self.id=id
    self.name=name
    self.salary=salary


  def show(self):
    print("Faculty id:", self.id)
    print("Faculty name:", self.name)
    print("Faculty salary:", self.salary)

# %%
info= Faculty(1,"Jhon",50000)

# %%
info.show()
# Out:
# Faculty id: 1
# Faculty name: Jhon
# Faculty salary: 50000

# %% [markdown]
# Inheritance

# %%
class Animal:
  def __init__(self,name):
    self.name=name

  def speak(self):
    return f"{self.name} makes sound"

class Dog(Animal):
  def speak(self):
    return f"{self.name} barks"

class Cat(Animal):
  def speak(self):
    return f"{self.name} meows"

# %%
animal=Animal("Generic Animal")
print(animal.speak())
# Out:
# Generic Animal makes sound

# %%
dog = Dog("Max")
print(dog.speak())
# Out:
# Max barks

# %%
cat=Cat("Jasmine")
print(cat.speak())
# Out:
# Jasmine meows

# %% [markdown]
# Polymorphism
#
#
# *   Poly=many
# *morphism=forms
# *i.e code being repeated in different form

# %%
def add (d,e,f=0,g=0):
  print(d+e+f+g)


add(20,50,70)            #overloading
# Out:
# 140

# %%
def sum(a,b):
  print(a+b)

def sum(a,b,c):          #overloading
  print(a+b+c)

sum(10,20,30)
# Out:
# 60

# %%
def multiply(a,b):
  print(a*b)



multiply(10,20)
# Out:
# 200

# %%
#overriding

class Animal:
  def sound(Revathi):
    return "Some Generic Sound"

class Dog(Animal):
  def sound(Revathi):
    return "Barks"

class Cat(Animal):
  def sound(Revathi):
    return "Meows"

class Cat(Animal):
  def sound(Revathi):
    return "Meow"

#Creating Objects

animal=Animal()
dog=Dog()
cat=Cat()

#Calling Methods

print(animal.sound())
print(dog.sound())
print(cat.sound())
# Out:
# Some Generic Sound
# Barks
# Meow

# %%
#Method Overlaoding


class MathOperations:
  def add(self,a=0,b=0,c=0,d=0,e=0):
      return a+b+c+d

math_op=MathOperations()

print(math_op.add(2,3,3,4,5))
# Out:
# 12

# %% [markdown]
# Exception Handling in Python
#
#
#
# *   Commom Exceptions in python
#
#
# 1.  ZeroDivisionError
# 2.  TypeError
# 3.  ValeError
# 4.FileNotFoundError

# %%
a=int(input("Enter A value for a"))

b= int(input("Enter A value for b"))

c=a/b

print(c)
# Out:
# Enter A value for a10
# Enter A value for b0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-bff3537525f8> in <cell line: 0>()
#       3 b= int(input("Enter A value for b"))
#       4
# ----> 5 c=a/b
#       6
#       7 print(c)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Syntax of Exception Handling:
#
# *   Try
# *   Except
# *   else
# *   finally

# %%
try:
     num=float(input("Enter a Number:\n"))   #Float= int, decimal number.   int=interger,no decimal number
     result=50/num
     print(f"result:{result}")
except ValueError:
     print("Error:could not convert string to float: ")
else:
     print("The code is good")
finally:
      print("this finally block is optional and will execute regardless of an erroe")
# Out:
# Enter a Number:
# revathi
# Error:could not convert string to float:
# this finally block is optional and will execute regardless of an erroe

# %%
try:
    num1=int(input("Enter the first number\n"))
    num2=int(input("Enter the second number\n"))
    result=num1/num2
    print(f"result:{result}")

except ZeroDivisionError:
  print("Error: Zero Division")
except ValueError:
  print("Error: Value Error")
except Exception as e:
  print(f"An unexpected error occured:{e}")
else:
  print("execution is succesfull")
# Out:
# Enter the first number
# 454
# Enter the second number
# kl
# Error: Value Error

# %% [markdown]
# Advanced Data Structures/Collections in Python
#
#
# *   deque
# *   namedtuple
# *   ChainMap
# *   Counter
# *   OrderedDict
# *   defaultdict

# %% [markdown]
# 1.Deque(Double Ended Queue)
#
#
#
# *   A deque(pronounced "deck") is a lisi like container that allows fast appends and pops from both ends
# *   Use Cases: Deques are useful when you need to add or remove elements from both the front and back of a queue

# %%
from collections import deque

#create a deque
d = deque()

#Add elements to the deque
d.append(1)
d.appendleft(2)
print(d)

#remove elements from the deque
d.pop()
d.popleft()
print(d)
d.extend([1,2,3])
print(d)
d.extendleft([6,5,4])
print(d)
# Out:
# deque([2, 1])
# deque([])
# deque([1, 2, 3])
# deque([4, 5, 6, 1, 2, 3])

# %%
from collections import deque

my_deque = deque([1,2,3,4,5])

print("Initial deque:",my_deque)

my_deque.append(6)
print("After appending 6 to the right:",my_deque)

my_deque.appendleft(0)
print("After appending 0 to the left:",my_deque)

popped_right = my_deque.pop()
print(f"After popping from the right({popped_right}removed):",my_deque)

popped_left = my_deque.popleft()
print(f"After popping from the left({popped_left}removed):",my_deque)

my_deque.extend([7,8])
print("After extending deque on the right with [7,8]:",my_deque)

my_deque.extendleft([-2,-1])
print("After extending deque on the left with [-2,-1]:",my_deque)

my_deque.rotate(2)
print("After rotating right by 2:",my_deque)

my_deque.rotate(-2)
print("After rotating left by 2:",my_deque)

my_deque.clear()
print("After clearing the deque:",my_deque)
# Out:
# Initial deque: deque([1, 2, 3, 4, 5])
# After appending 6 to the right: deque([1, 2, 3, 4, 5, 6])
# After appending 0 to the left: deque([0, 1, 2, 3, 4, 5, 6])
# After popping from the right(6removed): deque([0, 1, 2, 3, 4, 5])
# After popping from the left(0removed): deque([1, 2, 3, 4, 5])
# After extending deque on the right with [7,8]: deque([1, 2, 3, 4, 5, 7, 8])
# After extending deque on the left with [-2,-1]: deque([-1, -2, 1, 2, 3, 4, 5, 7, 8])
# After rotating right by 2: deque([7, 8, -1, -2, 1, 2, 3, 4, 5])
# After rotating left by 2: deque([-1, -2, 1, 2, 3, 4, 5, 7, 8])
# After clearing the deque: deque([])

# %% [markdown]
# 2.namedtuple

# %%
from collections import namedtuple

Person=namedtuple('Person',['name','age','city'])

person1= Person(name='john doe',age=30,city='new york')

print(person1.name)
print(person1.age)
print(person1.city)
# Out:
# john doe
# 30
# new york

# %% [markdown]
# 3.ChainMap

# %%
from collections import ChainMap

dict1={'a':1,'b':2}
dict2={'b':3,'c':4}

combined=ChainMap(dict1,dict2)

print(combined['a'])
print(combined['b'])
print(combined['c'])
print(combined.maps[1]['b'])
# Out:
# 1
# 2
# 4
# 3

# %% [markdown]
# 4.Counter

# %%
from collections import Counter

fruits=['apple','bana','apple','orange','banana','apple']
counter=Counter(fruits)

print(counter)

print(counter['apple'])
print(counter['banana'])
# Out:
# Counter({'apple': 3, 'bana': 1, 'orange': 1, 'banana': 1})
# 3
# 1

# %%
from collections import Counter

a=[1,2,'STRING',4,1,2,5,6,8,9,6,2,5,1,8,9,4,3,7,5,8,8,3,1,5]
counter=Counter(a)
print(counter)
print(counter[4])
# Out:
# Counter({1: 4, 5: 4, 8: 4, 2: 3, 4: 2, 6: 2, 9: 2, 3: 2, 'STRING': 1, 7: 1})
# 2

# %%
php install gtts

from gtts import gTTs
import os

Text = "Hello,this is a simple example of text to speak conversion.I would like to welcome everybody to todays class"

speech=gTT

# %%
from google.colab import drive'
drive.mount('/content/drive')

plp install SpeechRecognition pydub

import speech_recongnition as sr
from pydub import AudioSegment

mp3_file_path= '/context/drive/My Drive/python:Teaching material/

# %%
import
