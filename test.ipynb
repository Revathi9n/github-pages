# %% [markdown]
# <a href="https://colab.research.google.com/github/Revathi9n/github-pages/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#What is Python
#Python is a high level interpreted and object orinted programming language.
#It was created by Guido van rossum and first released in 1991.

# %%
#Key features of python
#1.Easy to read and write
#2.Interpreted language
#3.object oriented
#4.versatile and extensible
#5.large standard library
#6.cross platform

#Application of python
#1.web development
#2.Data science and machine learing
#3.Automation and scripting
#4.Game development
#5.Arificial Intelligence

# %%
A=10

# %%
A
# Out:
# 10

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
A="Python Programming"

# %%
A.lower()
# Out:
# 'python programming'

# %%
A.upper()
# Out:
# 'PYTHON PROGRAMMING'

# %%
A.title()
# Out:
# 'Python Programming'

# %%
A.isalpha()
# Out:
# False

# %%
A.isalnum()
# Out:
# False

# %%
S="Data Science"

# %%
S[5:]
# Out:
# 'Science'

# %%
S[0:4]
# Out:
# 'Data'

# %%
S[ : ]
# Out:
# 'Data Science'

# %%
S[0:10]
# Out:
# 'Data Scien'

# %% [markdown]
# Arithmetic Operations

# %%
x=10
y=20
addition = x+y
print(f"addition:{x}+{y} ={addition}")
# Out:
# addition:10+20 =30

# %%
x=8
y=9
subtraction=x-y
print(f"subtraction:{x}-{y}={subtraction}")
# Out:
# subtraction:8-9=-1

# %%
x=16
y=4
multiplication=x*y
print(f"multiplication:{x}*{y}={multiplication}")
# Out:
# multiplication:16*4=64

# %% [markdown]
# Conditional Statements

# %%
Tomato=15
if Tomato<=20:
  print("bring 1kg of Tomato")
# Out:
# bring 1kg of Tomato

# %%
tomato = int(input("tomatotes cost per kg:\n"))
if tomato<40:
  print("bring 5 kg of tomatotes")
elif tomato<=50:
  print("print 2kg of tomatotes")
else:
  print("bring 1kg of tomatotes")
# Out:
# tomatotes cost per kg:
# 90
# bring 1kg of tomatotes

# %%
age=int(input())
has_permission=True
if age>=18:
  if has_permission:
    print("Allowed")
  else:
    print("Not Allowed")
else:
  if age>=13:
    print("Allowed with Guardian")
  else:
    print("You are not allowed")
# Out:
# 2
# You are not allowed

# %%
Name =input()

if Name =="Rahul":
  print("Welcome Rahul")
elif Name == "Sanju":
  print("Welcome Sanju")
else:
  print("What's your name ?")
# Out:
# rahul
# What's your name ?

# %%
x = int(input("Enter a value for x:\n"))     #15
if x > 10:
    print("x is greater than 10")
    if x > 20:
        print("x is also greater than 20")
    else:
        print("x is not greater than 20")
else:
    print("x is 10 or less")
# Out:
# Enter a value for x:
# 2
# x is 10 or less

# %%
for i in [1,2,3,4,5]:
  print(i*10,end =',')
# Out:
# 10,20,30,40,50,

# %%
numbers = [1,'a',2,'b',3,4,5]
for num in numbers:
    print(num,end='')
# Out:
# 1a2b345

# %%
for i in [1,2,3,4,5]:
    print(i+10,end=',')
# Out:
# 11,12,13,14,15,

# %%
for i in [1,2,3,4,5]:
    print(i*"*")
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(n):
  print(""*(n-i-1)+"*"*(i+1))
for i in range(n-2,-1,-1):
    print(""*(n-i-1)+"*"*(i+1))
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
n=5
#upper part of the diamond
for i in range(1,n+1):   #1,2,3,4,5
  print(("*"*(2*i-1)).center(2*n-1))
#lower part of the diamond
for j in range(n-1,0,-1):    #4,3,2,1
  print(("*"*(2*j-1)).center(2*n-1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
import numpy as np
x=np.array([2,4,6,8,10])
print(x)
# Out:
# [ 2  4  6  8 10]

# %%
import numpy as np
np.random.randint(0,10,6)
# Out:
# array([2, 5, 1, 8, 7, 8])

# %%
array=np.random.randint(0,10,(3,4))
array
# Out:
# array([[3, 5, 3, 7],
#        [7, 5, 3, 2],
#        [4, 6, 7, 5]])

# %%
import numpy as np

def sum_arrays(*arrays):
    return np.sum(arrays,axis=0)

arr1 = np.array([[1,2],[3,4]])
arr2 = np.array([[5,6],[7,8]])
arr3 = np.array([[9,10],[11,12]])

result = sum_arrays(arr1,arr2,arr3)
print("Summed Array:\n",result)
# Out:
# Summed Array:
#  [[15 18]
#  [21 24]]
